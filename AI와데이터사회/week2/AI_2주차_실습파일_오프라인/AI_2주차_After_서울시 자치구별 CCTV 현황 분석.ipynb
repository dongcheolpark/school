# %% [markdown]
# # 서울시 자치구별 CCTV 현황 데이터 분석

# %% [markdown]
# # 1. 서울시 자치구별 CCTV 현황 데이터 읽어오기

# %%
import pandas as pd

# Colab에서는 파일의경로명을 해당 파일 옆에 점 세개 버튼의 경로 복사로 복사해 사용
#예) CCTV_Seoul = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/AI_2주차_실습파일_오프라인/서울시 CCTV 설치운영 현황(자치구)-연도별.csv',encoding='cp949')

CCTV_Seoul = pd.read_csv('./cctv.csv',encoding='cp949')
CCTV_Seoul
# Out:
#       구분     총계  2011년 이전  2011년  2012년  2013년  2014년  2015년  2016년  2017년  \
# 0      계  75431      5901   1619   2228      0   4368   6742   8300  10100
# 1    종로구   1729       216      7     10    582    210    150      1    259
# 2     중구   2001        16      6    199     90    125    218    333    462
# 3    용산구   2383        31      3     71    234    125    221    298    351
# 4    성동구   3515       487     26    122    207    112    335    309    790
# 5    광진구   2556        11     24     57    100    187     98     52    675
# 6   동대문구   2315       960    130    146     60     29    111    233    136
# 7    중랑구   3285       298     21     23    253     88    138    159    152
# 8    성북구   3754        42     41     87    174    230    323    587    461
# 9    강북구   2462         0      0      0     55     85    130    311     34
# 10   도봉구   1356         0     49     29     96    181     79    159    134
# 11   노원구   2282         0      0     90    105    109    605    405    256
# 12   은평구   3660        14      0      3     44    332    329    555    403
# 13  서대문구   2939       386    179    233    214    114    109    277    415
# 14   마포구   2401       270     66     93     77     61    162    350    358
# 15   양천구   3307      1217    282    175    201    173    193    351    120
# 16   강서구   2437        26     29    129    106    213    188    168    506
# 17   구로구   4075       643    209    216    349    187    268    326    540
# 18   금천구   2365         0      0      0    178     80    361    133    196
# 19  영등포구   3773       450    122    136    238    123    209    248    311
# 20   동작구   2262       165     73     93     29    503    130    254    278
# 21   관악구   4909       320    120     84    431    441    608    620    684
# 22   서초구   3730         0    117     72     93     71    563    516   1061
# 23   강남구   6645        62     61     72    368    455    845   1307   1004
# 24   송파구   2743        64      9     61     86     85    215    146    241
# 25   강동구   2547       223     45     27    227     49    154    202    273
#
#     2018년  2019년  2020년
# 0    9687  11657  10232
# 1      85      9    200
# 2     228    194    130
# 3     125    307    617
# 4     409    262    456
# 5     465    712    175
# 6     197    209    104
# 7     173   1050    930
# 8     860    716    233
# 9     385    976    486
# 10    223    214    192
# 11    201    240    271
# 12    635   1057    288
# 13    246    328    438
# 14    340    384    240
# 15    142    255    198
# 16    259    457    356
# 17    488    434    415
# 18    540    369    508
# 19    658     65   1213
# 20    255    242    240
# 21    674    596    331
# 22    436    361    440
# 23    744    796    931
# 24    542   1068    226
# 25    377    356    614

# %% [markdown]
# # 2. CCTV 현황 데이터 살펴보기

# %%
#데이터의 행x열 개수,컬럼,인덱스 정보 보기
print(CCTV_Seoul.shape)
print(CCTV_Seoul.index)
print(CCTV_Seoul.columns)
# Out:
# (26, 13)
# RangeIndex(start=0, stop=26, step=1)
# Index(['구분', '총계', '2011년 이전', '2011년', '2012년', '2013년', '2014년', '2015년',
#        '2016년', '2017년', '2018년', '2019년', '2020년'],
#       dtype='object')

# %%
#데이터의 위에서 5행 보기
CCTV_Seoul.head()
# Out:
#     구분     총계  2011년 이전  2011년  2012년  2013년  2014년  2015년  2016년  2017년  \
# 0    계  75431      5901   1619   2228      0   4368   6742   8300  10100
# 1  종로구   1729       216      7     10    582    210    150      1    259
# 2   중구   2001        16      6    199     90    125    218    333    462
# 3  용산구   2383        31      3     71    234    125    221    298    351
# 4  성동구   3515       487     26    122    207    112    335    309    790
#
#    2018년  2019년  2020년
# 0   9687  11657  10232
# 1     85      9    200
# 2    228    194    130
# 3    125    307    617
# 4    409    262    456

# %%
#데이터의 아래에서 5행 보기
CCTV_Seoul.tail()
# Out:
#      구분    총계  2011년 이전  2011년  2012년  2013년  2014년  2015년  2016년  2017년  \
# 21  관악구  4909       320    120     84    431    441    608    620    684
# 22  서초구  3730         0    117     72     93     71    563    516   1061
# 23  강남구  6645        62     61     72    368    455    845   1307   1004
# 24  송파구  2743        64      9     61     86     85    215    146    241
# 25  강동구  2547       223     45     27    227     49    154    202    273
#
#     2018년  2019년  2020년
# 21    674    596    331
# 22    436    361    440
# 23    744    796    931
# 24    542   1068    226
# 25    377    356    614

# %%
#데이터의 통계정보 보기
CCTV_Seoul.describe()
# Out:
#                  총계     2011년 이전        2011년        2012년       2013년  \
# count     26.000000    26.000000    26.000000    26.000000   26.000000
# mean    5802.384615   453.923077   124.538462   171.384615  176.807692
# std    14243.300744  1153.586266   313.384522   424.613337  136.795035
# min     1356.000000     0.000000     0.000000     0.000000    0.000000
# 25%     2369.500000    14.500000     7.500000    36.000000   87.000000
# 50%     2649.500000   114.500000    43.000000    85.500000  140.000000
# 75%     3712.500000   369.500000   119.250000   134.250000  232.250000
# max    75431.000000  5901.000000  1619.000000  2228.000000  582.000000
#
#              2014년        2015년        2016년         2017년        2018년  \
# count    26.000000    26.000000    26.000000     26.000000    26.000000
# mean    336.000000   518.615385   638.461538    776.923077   745.153846
# std     832.063988  1283.423424  1582.773167   1919.477344  1835.587224
# min      29.000000    79.000000     1.000000     34.000000    85.000000
# 25%      85.750000   141.000000   176.500000    244.750000   224.250000
# 50%     125.000000   212.000000   303.500000    354.500000   381.000000
# 75%     212.250000   333.500000   391.500000    531.500000   541.500000
# max    4368.000000  6742.000000  8300.000000  10100.000000  9687.000000
#
#               2019년         2020년
# count     26.000000     26.000000
# mean     896.692308    787.076923
# std     2216.506346   1945.202487
# min        9.000000    104.000000
# 25%      245.250000    227.750000
# 50%      365.000000    343.500000
# 75%      715.000000    502.500000
# max    11657.000000  10232.000000

# %%
#데이터의 타입, 아이템 수, 누락데이터 등 보기
CCTV_Seoul.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   구분        26 non-null     object
#  1   총계        26 non-null     int64
#  2   2011년 이전  26 non-null     int64
#  3   2011년     26 non-null     int64
#  4   2012년     26 non-null     int64
#  5   2013년     26 non-null     int64
#  6   2014년     26 non-null     int64
#  7   2015년     26 non-null     int64
#  8   2016년     26 non-null     int64
#  9   2017년     26 non-null     int64
#  10  2018년     26 non-null     int64
#  11  2019년     26 non-null     int64
#  12  2020년     26 non-null     int64
# dtypes: int64(12), object(1)
# memory usage: 2.8+ KB

# %% [markdown]
# # 3. CCTV 현황 데이터 정리하기

# %%
#CCTV_Seoul 데이터의 0번째 열이름을 '구분' -> '구별'로 변경 (columns={'구분' : '구별'})
CCTV_Seoul.rename(columns={'구분' : '구별'}, inplace=True)
CCTV_Seoul.head()
# Out:
#     구별     총계  2011년 이전  2011년  2012년  2013년  2014년  2015년  2016년  2017년  \
# 0    계  75431      5901   1619   2228      0   4368   6742   8300  10100
# 1  종로구   1729       216      7     10    582    210    150      1    259
# 2   중구   2001        16      6    199     90    125    218    333    462
# 3  용산구   2383        31      3     71    234    125    221    298    351
# 4  성동구   3515       487     26    122    207    112    335    309    790
#
#    2018년  2019년  2020년
# 0   9687  11657  10232
# 1     85      9    200
# 2    228    194    130
# 3    125    307    617
# 4    409    262    456

# %%
#다른 데이터들과 년도를 동일하게 맞추기 위해 '2020년' 열 삭제 (columns='2020년')
CCTV_Seoul.drop(columns='2020년', axis=1, inplace=True)
CCTV_Seoul.head()
# Out:
#     구별     총계  2011년 이전  2011년  2012년  2013년  2014년  2015년  2016년  2017년  \
# 0    계  75431      5901   1619   2228      0   4368   6742   8300  10100
# 1  종로구   1729       216      7     10    582    210    150      1    259
# 2   중구   2001        16      6    199     90    125    218    333    462
# 3  용산구   2383        31      3     71    234    125    221    298    351
# 4  성동구   3515       487     26    122    207    112    335    309    790
#
#    2018년  2019년
# 0   9687  11657
# 1     85      9
# 2    228    194
# 3    125    307
# 4    409    262

# %%
#'2017년 이전' 열 추가
CCTV_Seoul['2017년 이전']= CCTV_Seoul['총계'] - (CCTV_Seoul['2017년'] + CCTV_Seoul['2018년'] + CCTV_Seoul['2019년'])
CCTV_Seoul.head()
# Out:
#     구별     총계  2011년 이전  2011년  2012년  2013년  2014년  2015년  2016년  2017년  \
# 0    계  75431      5901   1619   2228      0   4368   6742   8300  10100
# 1  종로구   1729       216      7     10    582    210    150      1    259
# 2   중구   2001        16      6    199     90    125    218    333    462
# 3  용산구   2383        31      3     71    234    125    221    298    351
# 4  성동구   3515       487     26    122    207    112    335    309    790
#
#    2018년  2019년  2017년 이전
# 0   9687  11657     43987
# 1     85      9      1376
# 2    228    194      1117
# 3    125    307      1600
# 4    409    262      2054

# %%
#불필요한 년도의 열('2011년 이전', '2011년', '2012년', '2013년', '2014년','2015년','2016년') 삭제
CCTV_Seoul.drop(columns=['2011년 이전', '2011년', '2012년', '2013년', '2014년','2015년','2016년'], axis=1, inplace=True)
CCTV_Seoul.head()
# Out:
#     구별     총계  2017년  2018년  2019년  2017년 이전
# 0    계  75431  10100   9687  11657     43987
# 1  종로구   1729    259     85      9      1376
# 2   중구   2001    462    228    194      1117
# 3  용산구   2383    351    125    307      1600
# 4  성동구   3515    790    409    262      2054

# %%
#불필요한 행(index=0) 삭제
CCTV_Seoul.drop(index=0, axis=0, inplace=True)
CCTV_Seoul.head()
# Out:
#     구별    총계  2017년  2018년  2019년  2017년 이전
# 1  종로구  1729    259     85      9      1376
# 2   중구  2001    462    228    194      1117
# 3  용산구  2383    351    125    307      1600
# 4  성동구  3515    790    409    262      2054
# 5  광진구  2556    675    465    712       704

# %%
 #기존의 인덱스는 버리고 새로 설정
CCTV_Seoul.reset_index(drop=True, inplace=True)
CCTV_Seoul.head()
# Out:
#     구별    총계  2017년  2018년  2019년  2017년 이전
# 0  종로구  1729    259     85      9      1376
# 1   중구  2001    462    228    194      1117
# 2  용산구  2383    351    125    307      1600
# 3  성동구  3515    790    409    262      2054
# 4  광진구  2556    675    465    712       704

# %% [markdown]
# # 4. CCTV 현황데이터 자세히 보기

# %% [markdown]
# ### 4-1. CCTV의 전체 개수가 가장 적은/가장 많은 상위 5개 구는 어디일까?

# %%
#데이터 '총계'열을 기준으로 오름차순 정렬하기 (by='총계', ascending = True)

CCTV_Seoul.sort_values(by='총계', ascending=True).head(5)
# Out:
#      구별    총계  2017년  2018년  2019년  2017년 이전
# 9   도봉구  1356    134    223    214       785
# 0   종로구  1729    259     85      9      1376
# 1    중구  2001    462    228    194      1117
# 19  동작구  2262    278    255    242      1487
# 10  노원구  2282    256    201    240      1585

# %%
#데이터 '총계'열을 기준으로 내림차순 정렬하기 (by='총계', ascending = False)

CCTV_Seoul.sort_values(by='총계', ascending=False).head(5)
# Out:
#       구별    총계  2017년  2018년  2019년  2017년 이전
# 22   강남구  6645   1004    744    796      4101
# 20   관악구  4909    684    674    596      2955
# 16   구로구  4075    540    488    434      2613
# 18  영등포구  3773    311    658     65      2739
# 7    성북구  3754    461    860    716      1717

# %% [markdown]
# ### 4-2. 최근 3년간 CCTV 증가율을 계산하여 '최근증가율' 을 알아보자.

# %%
#최근 3년간 CCTV 수를 더하고 2017년 이전 CCTV수로 나눠서 최근 3년간 CCTV 증가율 계산

CCTV_Seoul['최근증가율']=(CCTV_Seoul['2019년'] + CCTV_Seoul['2018년'] + CCTV_Seoul['2017년']) / CCTV_Seoul['2017년 이전']  * 100
CCTV_Seoul.head()
# Out:
#     구별    총계  2017년  2018년  2019년  2017년 이전       최근증가율
# 0  종로구  1729    259     85      9      1376   25.654070
# 1   중구  2001    462    228    194      1117   79.140555
# 2  용산구  2383    351    125    307      1600   48.937500
# 3  성동구  3515    790    409    262      2054   71.129503
# 4  광진구  2556    675    465    712       704  263.068182

# %% [markdown]
# ### 4-3. '최근증가율' 이 가장 높은 상위 5개구는 어디일까?

# %%
#'최근증가율'로 내림차순 정렬
CCTV_Seoul.sort_values(by='최근증가율', ascending=False).head()
# Out:
#      구별    총계  2017년  2018년  2019년  2017년 이전       최근증가율
# 4   광진구  2556    675    465    712       704  263.068182
# 23  송파구  2743    241    542   1068       892  207.511211
# 11  은평구  3660    403    635   1057      1565  133.865815
# 8   강북구  2462     34    385    976      1067  130.740394
# 7   성북구  3754    461    860    716      1717  118.637158

# %% [markdown]
# # 5. 서울시 인구현황 데이터 읽어오기

# %%
# Colab에서는 파일의 경로명을 해당 파일 옆에 점 세개 버튼의 경로 복사로 복사해 사용
# 예) pop_Seoul = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/AI_2주차_실습파일_오프라인/행정구역_시군구_별__성별_인구수_서울.xlsx')

pop_Seoul = pd.read_excel('./cctv.xlsx')
pop_Seoul
# Out:
#     행정구역(시군구)별  2019. 12 2019. 12.1 2019. 12.2
# 0   행정구역(시군구)별  총인구수 (명)  남자인구수 (명)  여자인구수 (명)
# 1            계   9729107    4744059    4985048
# 2          종로구    151290      73746      77544
# 3           중구    126171      61910      64261
# 4          용산구    228670     110356     118314
# 5          성동구    300889     147273     153616
# 6          광진구    351350     170262     181088
# 7         동대문구    346194     172113     174081
# 8          중랑구    397015     196959     200056
# 9          성북구    442650     214437     228213
# 10         강북구    313954     153235     160719
# 11         도봉구    333362     163051     170311
# 12         노원구    532905     257923     274982
# 13         은평구    480032     231528     248504
# 14        서대문구    309397     148663     160734
# 15         마포구    374035     176891     197144
# 16         양천구    458165     225186     232979
# 17         강서구    591796     286563     305233
# 18         구로구    406664     200987     205677
# 19         금천구    232810     118209     114601
# 20        영등포구    367678     182438     185240
# 21         동작구    395963     191976     203987
# 22         관악구    500094     251009     249085
# 23         서초구    430826     206039     224787
# 24         강남구    545169     260806     284363
# 25         송파구    675961     327164     348797
# 26         강동구    436067     215335     220732

# %%
# Colab에서는 파일의 경로명을 해당 파일 옆에 점 세개 버튼의 경로 복사로 복사해 사용
# 예) pop_Seoul = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/AI_2주차_실습파일_오프라인/행정구역_시군구_별__성별_인구수_서울.xlsx')

#header= 1 옵션은 액셀에서 두번째 줄부터 읽어옴 (숫자는 0부터 시작)
pop_Seoul = pd.read_excel('./cctv.xlsx', header=1) 
pop_Seoul.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/3k/kdv5qkf50flfh_b8hcs56n300000gn/T/ipykernel_75220/2587385427.py in <module>
#       3
#       4 #header= 1 옵션은 액셀에서 두번째 줄부터 읽어옴 (숫자는 0부터 시작)
# ----> 5 pop_Seoul = pd.read_excel('./행정구역_시군구_별__성별_인구수_서울.xlsx', header=1)
#       6 pop_Seoul.head()
#
# /opt/homebrew/anaconda3/envs/AI와데이터사회/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /opt/homebrew/anaconda3/envs/AI와데이터사회/lib/python3.9/site-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     362     if not isinstance(io, ExcelFile):
#     363         should_close = True
# --> 364         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     365     elif engine and engine != io.engine:
#     366         raise ValueError(
#
# /opt/homebrew/anaconda3/envs/AI와데이터사회/lib/python3.9/site-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1189                 ext = "xls"
#    1190             else:
# -> 1191                 ext = inspect_excel_format(
#    1192                     content_or_path=path_or_buffer, storage_options=storage_options
#    1193                 )
#
# /opt/homebrew/anaconda3/envs/AI와데이터사회/lib/python3.9/site-packages/pandas/io/excel/_base.py in inspect_excel_format(content_or_path, storage_options)
#    1068         content_or_path = BytesIO(content_or_path)
#    1069
# -> 1070     with get_handle(
#    1071         content_or_path, "rb", storage_options=storage_options, is_text=False
#    1072     ) as handle:
#
# /opt/homebrew/anaconda3/envs/AI와데이터사회/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     708         else:
#     709             # Binary mode
# --> 710             handle = open(handle, ioargs.mode)
#     711         handles.append(handle)
#     712
#
# FileNotFoundError: [Errno 2] No such file or directory: './행정구역_시군구_별__성별_인구수_서울.xlsx'

# %%
#데이터의 행,열 개수,컬럼,인덱스 정보 보기
print(pop_Seoul.shape)
print(pop_Seoul.index)
print(pop_Seoul.columns)
# Out:
# (27, 4)
# RangeIndex(start=0, stop=27, step=1)
# Index(['행정구역(시군구)별', '2019. 12', '2019. 12.1', '2019. 12.2'], dtype='object')

# %% [markdown]
# # 6. 인구 현황 데이터 정리하기

# %%
#컬럼 이름 변경
pop_Seoul.rename(columns={'행정구역(시군구)별':'구별',
                          '총인구수 (명)':'인구수',
                          '남자인구수 (명)':'남성',
                          '여자인구수 (명)': '여성'}, inplace=True)
pop_Seoul.head()
# Out:
#     구별      인구수       남성       여성
# 0    계  9729107  4744059  4985048
# 1  종로구   151290    73746    77544
# 2   중구   126171    61910    64261
# 3  용산구   228670   110356   118314
# 4  성동구   300889   147273   153616

# %%
#불필요한 행 삭제, 0번 인덱스 줄 삭제
pop_Seoul.drop(index=0, axis=0, inplace=True)
pop_Seoul.head()
# Out:
#     구별     인구수      남성      여성
# 1  종로구  151290   73746   77544
# 2   중구  126171   61910   64261
# 3  용산구  228670  110356  118314
# 4  성동구  300889  147273  153616
# 5  광진구  351350  170262  181088

# %%
#인덱스 새로 설정
pop_Seoul.reset_index(drop=True, inplace=True)
pop_Seoul.head()
# Out:
#     구별     인구수      남성      여성
# 0  종로구  151290   73746   77544
# 1   중구  126171   61910   64261
# 2  용산구  228670  110356  118314
# 3  성동구  300889  147273  153616
# 4  광진구  351350  170262  181088

# %% [markdown]
# # 7. 인구현황 데이터 자세히 보기

# %% [markdown]
# ### 7-1. 인구수가 가장 높은 상위 5개 구는 어디일까?

# %%
#'인구수'로 내림차순 정렬
pop_Seoul.sort_values(by='인구수',ascending=False).head()
# Out:
#      구별     인구수      남성      여성
# 23  송파구  675961  327164  348797
# 15  강서구  591796  286563  305233
# 22  강남구  545169  260806  284363
# 10  노원구  532905  257923  274982
# 20  관악구  500094  251009  249085

# %% [markdown]
# ###  7-2. 여성인구와 남성인구 비율을 알아보자

# %%
pop_Seoul['여성비율'] = pop_Seoul['여성'] / pop_Seoul['인구수'] * 100
pop_Seoul['남성비율'] = pop_Seoul['남성'] / pop_Seoul['인구수'] * 100
pop_Seoul.head()
# Out:
#     구별     인구수      남성      여성       여성비율       남성비율
# 0  종로구  151290   73746   77544  51.255205  48.744795
# 1   중구  126171   61910   64261  50.931672  49.068328
# 2  용산구  228670  110356  118314  51.740062  48.259938
# 3  성동구  300889  147273  153616  51.054043  48.945957
# 4  광진구  351350  170262  181088  51.540629  48.459371

# %% [markdown]
# ### 7-3. 여성비율이 가장 높은 상위 5개 구는 어디일까?

# %%
#'여성비율'로 내림차순 정렬

pop_Seoul.sort_values(by='여성비율',ascending=False).head()
# Out:
#       구별     인구수      남성      여성       여성비율       남성비율
# 13   마포구  374035  176891  197144  52.707367  47.292633
# 21   서초구  430826  206039  224787  52.175820  47.824180
# 22   강남구  545169  260806  284363  52.160523  47.839477
# 12  서대문구  309397  148663  160734  51.950730  48.049270
# 11   은평구  480032  231528  248504  51.768215  48.231785

# %% [markdown]
# ### 7-4. 남성비율이 가장 높은 상위 5개 구는 어디일까?

# %%
#'남성비율'로 내림차순 정렬
pop_Seoul.sort_values(by='남성비율', ascending=False).head()
# Out:
#       구별     인구수      남성      여성       여성비율       남성비율
# 17   금천구  232810  118209  114601  49.225119  50.774881
# 20   관악구  500094  251009  249085  49.807636  50.192364
# 5   동대문구  346194  172113  174081  50.284234  49.715766
# 18  영등포구  367678  182438  185240  50.381040  49.618960
# 6    중랑구  397015  196959  200056  50.390036  49.609964

# %% [markdown]
# # 8. 데이터 합치기

# %% [markdown]
# ### 8-1. 인구 대비 CCTV 현황을 확인해 보자

# %%
# 두 데이터 합치기 (병합기준 열을 '구별'로 병합, on='구별')
data_result = pd.merge(CCTV_Seoul, pop_Seoul, on='구별')
data_result
# Out:
#       구별    총계  2017년  2018년  2019년  2017년 이전       최근증가율     인구수      남성  \
# 0    종로구  1729    259     85      9      1376   25.654070  151290   73746
# 1     중구  2001    462    228    194      1117   79.140555  126171   61910
# 2    용산구  2383    351    125    307      1600   48.937500  228670  110356
# 3    성동구  3515    790    409    262      2054   71.129503  300889  147273
# 4    광진구  2556    675    465    712       704  263.068182  351350  170262
# 5   동대문구  2315    136    197    209      1773   30.569656  346194  172113
# 6    중랑구  3285    152    173   1050      1910   71.989529  397015  196959
# 7    성북구  3754    461    860    716      1717  118.637158  442650  214437
# 8    강북구  2462     34    385    976      1067  130.740394  313954  153235
# 9    도봉구  1356    134    223    214       785   72.738854  333362  163051
# 10   노원구  2282    256    201    240      1585   43.974763  532905  257923
# 11   은평구  3660    403    635   1057      1565  133.865815  480032  231528
# 12  서대문구  2939    415    246    328      1950   50.717949  309397  148663
# 13   마포구  2401    358    340    384      1319   82.031842  374035  176891
# 14   양천구  3307    120    142    255      2790   18.530466  458165  225186
# 15   강서구  2437    506    259    457      1215  100.576132  591796  286563
# 16   구로구  4075    540    488    434      2613   55.951014  406664  200987
# 17   금천구  2365    196    540    369      1260   87.698413  232810  118209
# 18  영등포구  3773    311    658     65      2739   37.751004  367678  182438
# 19   동작구  2262    278    255    242      1487   52.118359  395963  191976
# 20   관악구  4909    684    674    596      2955   66.125212  500094  251009
# 21   서초구  3730   1061    436    361      1872   99.252137  430826  206039
# 22   강남구  6645   1004    744    796      4101   62.033650  545169  260806
# 23   송파구  2743    241    542   1068       892  207.511211  675961  327164
# 24   강동구  2547    273    377    356      1541   65.282284  436067  215335
#
#         여성       여성비율       남성비율
# 0    77544  51.255205  48.744795
# 1    64261  50.931672  49.068328
# 2   118314  51.740062  48.259938
# 3   153616  51.054043  48.945957
# 4   181088  51.540629  48.459371
# 5   174081  50.284234  49.715766
# 6   200056  50.390036  49.609964
# 7   228213  51.556083  48.443917
# 8   160719  51.191894  48.808106
# 9   170311  51.088906  48.911094
# 10  274982  51.600567  48.399433
# 11  248504  51.768215  48.231785
# 12  160734  51.950730  48.049270
# 13  197144  52.707367  47.292633
# 14  232979  50.850458  49.149542
# 15  305233  51.577402  48.422598
# 16  205677  50.576643  49.423357
# 17  114601  49.225119  50.774881
# 18  185240  50.381040  49.618960
# 19  203987  51.516682  48.483318
# 20  249085  49.807636  50.192364
# 21  224787  52.175820  47.824180
# 22  284363  52.160523  47.839477
# 23  348797  51.600166  48.399834
# 24  220732  50.618827  49.381173

# %% [markdown]
# ### 8-2. 인덱스 이름을 구이름으로 바꿔보자

# %%
data_result.set_index('구별', inplace=True)
data_result.head()
# Out:
#        총계  2017년  2018년  2019년  2017년 이전       최근증가율     인구수      남성      여성  \
# 구별
# 종로구  1729    259     85      9      1376   25.654070  151290   73746   77544
# 중구   2001    462    228    194      1117   79.140555  126171   61910   64261
# 용산구  2383    351    125    307      1600   48.937500  228670  110356  118314
# 성동구  3515    790    409    262      2054   71.129503  300889  147273  153616
# 광진구  2556    675    465    712       704  263.068182  351350  170262  181088
#
#           여성비율       남성비율
# 구별
# 종로구  51.255205  48.744795
# 중구   50.931672  49.068328
# 용산구  51.740062  48.259938
# 성동구  51.054043  48.945957
# 광진구  51.540629  48.459371

# %%
#합친 데이터 엑셀파일로 저장하기
#합친 데이터 엑셀파일로 저장하기
# Colab에서는 파일의 경로명을 해당 파일 옆에 점 세개 버튼의 경로 복사로 복사해 사용
# 예) excel_writer = pd.ExcelWriter('/content/drive/MyDrive/Colab Notebooks/AI_2주차_실습파일_오프라인/CCTV_pop.xlsx')

excel_writer = pd.ExcelWriter('./CCTV_pop.xlsx')
data_result.to_excel(excel_writer, index=True)
excel_writer.save()

# %% [markdown]
# # 9. 서울시 자치구별 CCTV 현황 분석하기

# %% [markdown]
# ### 9-1. CCTV 수에 가장 영향을 미치는 항목은 무엇일까?

# %%
import numpy as np

# 두 항목간의 상관계수 대각선을 제외하고 상관계수 절대값이 1에 가까울 수록 높은 상관 관계

np.corrcoef(data_result['여성비율'],data_result['총계'])
# Out:
# array([[1.        , 0.03541795],
#        [0.03541795, 1.        ]])

# %%
np.corrcoef(data_result['남성비율'],data_result['총계'])
# Out:
# array([[ 1.        , -0.03541795],
#        [-0.03541795,  1.        ]])

# %%
np.corrcoef(data_result['인구수'],data_result['총계'])
# Out:
# array([[1.        , 0.44163914],
#        [0.44163914, 1.        ]])

# %% [markdown]
# ### 9-2. CCTV 수에 가장 영향을 미치는 항목의 수가 가장 큰 구는 CCTV 수도 가장 큰가?

# %%
#'인구수'로 내림차순정렬
data_result.sort_values(by='인구수', ascending=False).head(5)
# Out:
#        총계  2017년  2018년  2019년  2017년 이전       최근증가율     인구수      남성      여성  \
# 구별
# 송파구  2743    241    542   1068       892  207.511211  675961  327164  348797
# 강서구  2437    506    259    457      1215  100.576132  591796  286563  305233
# 강남구  6645   1004    744    796      4101   62.033650  545169  260806  284363
# 노원구  2282    256    201    240      1585   43.974763  532905  257923  274982
# 관악구  4909    684    674    596      2955   66.125212  500094  251009  249085
#
#           여성비율       남성비율
# 구별
# 송파구  51.600166  48.399834
# 강서구  51.577402  48.422598
# 강남구  52.160523  47.839477
# 노원구  51.600567  48.399433
# 관악구  49.807636  50.192364

# %%
#CCTV수로 내림차순정렬
data_result.sort_values(by='총계', ascending=False).head(5)
# Out:
#         총계  2017년  2018년  2019년  2017년 이전       최근증가율     인구수      남성      여성  \
# 구별
# 강남구   6645   1004    744    796      4101   62.033650  545169  260806  284363
# 관악구   4909    684    674    596      2955   66.125212  500094  251009  249085
# 구로구   4075    540    488    434      2613   55.951014  406664  200987  205677
# 영등포구  3773    311    658     65      2739   37.751004  367678  182438  185240
# 성북구   3754    461    860    716      1717  118.637158  442650  214437  228213
#
#            여성비율       남성비율
# 구별
# 강남구   52.160523  47.839477
# 관악구   49.807636  50.192364
# 구로구   50.576643  49.423357
# 영등포구  50.381040  49.618960
# 성북구   51.556083  48.443917

# %% [markdown]
# ## 10. 서울시 자치구별 CCTV 현황 시각화

# %%
#한글폰트 깨짐 방지 코드

import matplotlib.pyplot as plt

import platform
path = "c:/windows/Fonts/malgun.ttf"
from matplotlib import font_manager, rc

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else :
    print('Unknown system... sorry~~~')

# %% [markdown]
# ### 10-1. CCTV수가 가장 많은 구는 어디인가?

# %%
#'총계'로 막대 그래프 그리기
data_result['총계'].plot(kind='barh', grid=True, figsize=(10,10))
plt.show()

# %%
# '총계'로 소팅하여 막대 그래프 그리기
data_result['총계'].sort_values().plot(kind='barh', grid=True, figsize=(10,10))
plt.show()

# %% [markdown]
# ### 10-2. CCTV의 비율(인구수에 대비 CCTV 수)이 가장 높은 구는 어디인가?

# %%
# 'CCTV비율' 열 추가
data_result['CCTV비율'] = data_result['총계'] / data_result['인구수'] * 100
data_result.head()
# Out:
#        총계  2017년  2018년  2019년  2017년 이전       최근증가율     인구수      남성      여성  \
# 구별
# 종로구  1729    259     85      9      1376   25.654070  151290   73746   77544
# 중구   2001    462    228    194      1117   79.140555  126171   61910   64261
# 용산구  2383    351    125    307      1600   48.937500  228670  110356  118314
# 성동구  3515    790    409    262      2054   71.129503  300889  147273  153616
# 광진구  2556    675    465    712       704  263.068182  351350  170262  181088
#
#           여성비율       남성비율    CCTV비율
# 구별
# 종로구  51.255205  48.744795  1.142838
# 중구   50.931672  49.068328  1.585943
# 용산구  51.740062  48.259938  1.042113
# 성동구  51.054043  48.945957  1.168205
# 광진구  51.540629  48.459371  0.727480

# %%
# 소팅한 CCTV비율 막대 그래프 (kind='barh', grid=True, figsize=(10,10))
data_result['CCTV비율'].sort_values().plot(kind='barh', grid=True, figsize=(10,10))
plt.show()

# %% [markdown]
# ### 10-3. 인구 수에 대한 CCTV수의 일반적인 분포를 살펴보자

# %%
plt.figure(figsize=(6,6))

# 인구수에 대한 CCTV 수 산점도 그래프
data_result.plot(kind='scatter', x='인구수', y='총계', s=50)
plt.xlabel('인구수')
plt.ylabel('CCTV')
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/3k/kdv5qkf50flfh_b8hcs56n300000gn/T/ipykernel_75129/2785962125.py in <module>
# ----> 1 plt.figure(figsize=(6,6))
#       2
#       3 # 인구수에 대한 CCTV 수 산점도 그래프
#       4 data_result.plot(kind='scatter', x='인구수', y='총계', s=50)
#       5 plt.xlabel('인구수')
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ### 10-4. 일반적인 기준에서 인구 수에 비해 CCTV 수가 많은 구와 적은 구는 어디인가?

# %%
# 데이터에 대한 대표선을 나타내는, 기울기, 절편을 fp1에 저장
fp1 = np.polyfit(data_result['인구수'], data_result['총계'], 1)
fp1
# Out:
# array([3.78940395e-03, 1.54253934e+03])

# %%
# 직선의 y값 생성시켜주는 함수
f1 = np.poly1d(fp1)
# 지정한 범위 내에서 데이터의 개수만큼 같은 간격의 숫자 생성, x축 숫자 생성
fx = np.linspace(100000, 700000, 100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/3k/kdv5qkf50flfh_b8hcs56n300000gn/T/ipykernel_75129/1755177801.py in <module>
#       1 # 직선의 y값 생성시켜주는 함수
# ----> 2 f1 = np.poly1d(fp1)
#       3 # 지정한 범위 내에서 데이터의 개수만큼 같은 간격의 숫자 생성, x축 숫자 생성
#       4 fx = np.linspace(100000, 700000, 100)
#
# NameError: name 'np' is not defined

# %%
# 산점도 그래프 그리기
plt.figure(figsize=(9,9))
plt.scatter(data_result['인구수'],data_result['총계'], s=50)

# 선그래프 그리기, 순서대로, x축 데이터, y축 데이터, ls는 선 스타일, lw는 선 굵기
plt.plot(fx, f1(fx), '--', lw=2, color='g')

#점 옆에 구이름 텍스트 넣기
for n in range(24):
    # *1을 곱하면 점과 동일한 위치
    plt.text(data_result['인구수'][n]*1.02, data_result['총계'][n]*0.98, data_result.index[n], fontsize=10)
    
plt.xlabel('인구수')
plt.ylabel('CCTV')
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/3k/kdv5qkf50flfh_b8hcs56n300000gn/T/ipykernel_75129/1449023760.py in <module>
#       1 # 산점도 그래프 그리기
#       2 plt.figure(figsize=(9,9))
# ----> 3 plt.scatter(data_result['인구수'],data_result['총계'], s=50)
#       4
#       5 # 선그래프 그리기, 순서대로, x축 데이터, y축 데이터, ls는 선 스타일, lw는 선 굵기
#
# NameError: name 'data_result' is not defined
